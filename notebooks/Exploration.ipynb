# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../run_log.csv", names=['step', 'train accuracy', 'test accuracy', 'train cross entropy', 'test cross entropy'])
df.head()
# Out:
#    step  train accuracy  test accuracy  train cross entropy  \
# 0     0            0.02           0.12             6.070060
# 1     5            0.08           0.22             3.111067
# 2    10            0.20           0.22             2.565627
# 3    15            0.28           0.28             2.221389
# 4    20            0.42           0.38             2.143417
#
#    test cross entropy
# 0            7.363458
# 1            3.251952
# 2            2.503300
# 3            2.574319
# 4            1.928253

# %%
json = df.to_json(orient='split')

# %%
df_from_json = pd.read_json(json, orient='split')

df_from_json.head()
# Out:
#    step  train accuracy  test accuracy  train cross entropy  \
# 0     0            0.02           0.12             6.070060
# 1     5            0.08           0.22             3.111067
# 2    10            0.20           0.22             2.565627
# 3    15            0.28           0.28             2.221389
# 4    20            0.42           0.38             2.143417
#
#    test cross entropy
# 0            7.363458
# 1            3.251952
# 2            2.503300
# 3            2.574319
# 4            1.928253
